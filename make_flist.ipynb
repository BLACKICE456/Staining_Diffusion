# %%
import os
my_files = os.listdir("png")
print(my_files)

listFiles = []
for files in my_files:
    if "png" in files:
        #print(files)
        listFiles.append(files[:-4])

listFiles.sort()
fo = open("jpg.txt", "w")
for fileName in listFiles:
    fo.write(fileName + "\n")
    print(fileName)
fo.close()

# %%
import os

path = r"D:\\paper_model\\BCI\BCI_dataset\\IHC\\train"

my_files = os.listdir(path)
print(my_files)

fo = open("IHC_train.flist","w")
for filename in my_files:
    fo.write(path + r"\\" + filename + "\n")
    print(path + r"\\" + filename + "\n")
fo.close
# Out:
# ['00000_train_1+.png', '00001_train_3+.png', '00002_train_3+.png', '00003_train_1+.png', '00004_train_1+.png', '00005_train_3+.png', '00006_train_2+.png', '00007_train_3+.png', '00008_train_2+.png', '00009_train_2+.png', '00010_train_3+.png', '00011_train_2+.png', '00012_train_2+.png', '00013_train_2+.png', '00014_train_3+.png', '00015_train_0.png', '00016_train_2+.png', '00017_train_3+.png', '00018_train_3+.png', '00019_train_1+.png', '00020_train_1+.png', '00021_train_2+.png', '00022_train_3+.png', '00023_train_1+.png', '00024_train_3+.png', '00025_train_1+.png', '00026_train_3+.png', '00027_train_1+.png', '00028_train_3+.png', '00029_train_2+.png', '00030_train_3+.png', '00031_train_2+.png', '00032_train_3+.png', '00033_train_2+.png', '00034_train_2+.png', '00035_train_2+.png', '00036_train_3+.png', '00037_train_2+.png', '00038_train_2+.png', '00039_train_1+.png', '00040_train_3+.png', '00041_train_2+.png', '00042_train_2+.png', '00043_train_2+.png', '00044_train_1+.png', '00045_t
# ...

# %%
from PIL import Image
path = r"D:\\paper_model\\BCI\BCI_dataset\\IHC\\train\\00012_train_2+.png"
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
import numpy as np
import os

flist = r'D:\paper_model\RDDM\RDDM-main\HE_test.flist'

# %%
def load_flist(flist):
        if isinstance(flist, list):
            print("1")
            return flist

        # flist: image file path, image directory path, text file flist path
        if isinstance(flist, str):
            print(os.path.isdir(flist))
            if os.path.isdir(flist):
                return [p for ext in exts for p in Path(f'{flist}').glob(f'**/*.{ext}')]

            if os.path.isfile(flist):
                try:
                    return np.genfromtxt(flist, dtype=np.str, encoding='utf-8')
                except:
                    return [flist]

        return []

# %%
a = load_flist(flist)
print(a)
print(os.path.isdir(flist))
isinstance(flist, str)
# Out:
# False
# ['D:\\paper_model\\RDDM\\RDDM-main\\HE_test.flist']
# False
# C:\Users\User\AppData\Local\Temp\ipykernel_5776\3558048454.py:14: FutureWarning: In the future `np.str` will be defined as the corresponding NumPy scalar.
#   return np.genfromtxt(flist, dtype=np.str, encoding='utf-8')
# True

# %%
path = r"D:\paper_model\BCI\BCI_dataset\IHC\train"

my_files = os.listdir(path)
print(my_files)
# Out:
# ['00000_train_1+.png', '00001_train_3+.png', '00002_train_3+.png', '00003_train_1+.png', '00004_train_1+.png', '00005_train_3+.png', '00006_train_2+.png', '00007_train_3+.png', '00008_train_2+.png', '00009_train_2+.png', '00010_train_3+.png', '00011_train_2+.png', '00012_train_2+.png', '00013_train_2+.png', '00014_train_3+.png', '00015_train_0.png', '00016_train_2+.png', '00017_train_3+.png', '00018_train_3+.png', '00019_train_1+.png', '00020_train_1+.png', '00021_train_2+.png', '00022_train_3+.png', '00023_train_1+.png', '00024_train_3+.png', '00025_train_1+.png', '00026_train_3+.png', '00027_train_1+.png', '00028_train_3+.png', '00029_train_2+.png', '00030_train_3+.png', '00031_train_2+.png', '00032_train_3+.png', '00033_train_2+.png', '00034_train_2+.png', '00035_train_2+.png', '00036_train_3+.png', '00037_train_2+.png', '00038_train_2+.png', '00039_train_1+.png', '00040_train_3+.png', '00041_train_2+.png', '00042_train_2+.png', '00043_train_2+.png', '00044_train_1+.png', '00045_t
# ...

# %%
path_list = []
for file in my_files:
    path_list.append(path + '\\' + file)

print(path_list)
# Out:
# ['D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00000_train_1+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00001_train_3+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00002_train_3+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00003_train_1+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00004_train_1+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00005_train_3+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00006_train_2+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00007_train_3+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00008_train_2+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00009_train_2+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00010_train_3+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00011_train_2+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00012_train_2+.png', 'D:\\paper_model\\BCI\\BCI_dataset\\IHC\\train\\00013_train_2+.png', 'D:\\paper_model\\BCI\\BCI_data
# ...

# %%
isinstance(path_list,list)
# Out:
# True
